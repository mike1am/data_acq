# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import re

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from pymongo.errors import OperationFailure

# import datetime as dt
import dotenv
import os

from pprint import pprint

dotenv.load_dotenv()
# Out:
# True

# %%
INIT_PARAMS = {
    'hhtmFrom': "vacancy_search_list",
    'hhtmFromLabel': "vacancy_search_line",
    'search_field': ["name", "company_name", "description"],
    'ored_clusters': True,
    'enable_snippets': False,
}

BASE_URL = "https://hh.ru"

INIT_LINK = "/search/vacancy/"

page_modif = lambda p: {'page': p}

HEADER = {
    'Accept': "*/*",
    'User-Agent': UserAgent().chrome,
    'Connection': "keep-alive",
}

# %%
params = INIT_PARAMS.copy()
params.update({
    'area': 1,
    'part_time': ['employment_part'],
    'salary': 70_000,
    # 'only_with_salary': True,
    'text': 'python'
})

# %%
def parseSal(salStr):
    """
    Парсит строку с зарплатой, полученной с HH
    Returns:
        кортеж:
        * диапазон зарплат (min, max), если max - 0, то без верхн. ограничения,
        * валюта,
        * строка описания, говорящая чистыми ли указаны суммы
    """
    salStr, *tax = salStr.split("\xa0")
    currency = salStr[-1]
    
    salStr = re.sub("\s", "", salStr[:-1]).replace("до", "–")
    if salStr[:2].lower() == "от":
        salStr = salStr.lstrip("от") + "–"
    valScopes = tuple(map(lambda s: int(s) if s else 0, salStr.split("–")))
    
    return {
        'scopes': valScopes,
        'currency': currency,
        'tax': tax[0] if tax else None
    }

# %%
def parseExp(expStr):
    return tuple(map(int, filter(bool, re.split("\D+", expStr))))

# %%
def parseSoup1(soup, data):
    """
    Просматривает soup и добавляет сведения о вакансиях в data
    """
    for card in soup.find_all("div", class_=re.compile("^vacancy-card")):
        cardDict = {}
        
        tag = card.findChild("span", class_=re.compile("^vacancy-name"))
        cardDict['position'] = tag.getText() if tag else None
        
        tag = card.findChild("div", class_=re.compile("^info-section")) \
            .findChild("a", class_=re.compile("^bloko-link"))
        cardDict['company'] = {
            'name': tag.findChild("span", class_=re.compile("^company-info-text")).getText() \
                .replace("\xa0", " ")
                if tag else None,
            'link': BASE_URL + tag.get("href") if tag else None
        }

        tag = card.findChild("div", class_=re.compile("^compensation-labels"))
        
        tag1 = tag.findChild("span", class_=re.compile("^compensation-text")) if tag else None
        cardDict['salary'] = parseSal(tag1.getText()) if tag1 else None
        
        tag1 = tag.findChild("span", attr={'data-qa': re.compile("work-experience$")}) if tag else None
        cardDict['experience'] = parseExp(tag1.getText()) if tag1 else None

        tag1 = tag.findChild("span", attr={'data-qa': re.compile("work-schedule$")}) if tag else None
        cardDict['schedule'] = tag1.getText().replace("\xa0", " ") if tag1 else None
            
        data.append(cardDict)

# %%
def parseSoup2(soup, data):
    """
    Просматривает soup и добавляет сведения о вакансиях в data
    """
    for card in soup.find_all("div", class_="vacancy-serp-item__layout"):
        cardDict = {}
        
        tag = card.findChild("span", class_=re.compile("title$"))
        cardDict['position'] = tag.getText() if tag else None
        
        tag = card.findChild("div", class_=re.compile("info-company$")).findChild("a")
        cardDict['company'] = (
            tag.findChild("span").getText().replace("\xa0", " ") if tag else None,
            BASE_URL + tag.get("href") if tag else None
        )

        tag = card.findChild("span", attrs={'data-qa': re.compile("vacancy-compensation$")})
        cardDict['salary'] = parseSal(tag.getText()) if tag else None

        tag = card.findChild("div", attrs={'data-qa': re.compile("work-experience$")})
        cardDict['experience'] = parseExp(tag.getText()) if tag else None

        tag = card.findChild("span", attrs={'data-qa': re.compile("work-schedule$")})
        cardDict['schedule'] = tag.getText().replace("\xa0", " ") if tag else None

        data.append(cardDict)

# %%
def isNextExists(soup):
    return bool(soup.find("a", {'data-qa': "pager-next"}))

# %%
session = requests.session() # для оптимизации повторных запросов
pageNum = 0
nextExists = True
parseData = []

while nextExists:
    params.update(page_modif(pageNum))
    response = session.get(BASE_URL + INIT_LINK, params=params, headers=HEADER)
    # with open("hh.html", "wb") as f:
    #     f.write(response.content)

    soup = BeautifulSoup(response.text, features="html.parser")
    
    variant = 1 if soup.find("div", class_=re.compile("^vacancy-card")) else 2
    
    if not response.ok:
        print("!", end="")
        continue
    elif variant == 1:
        print("*", end="")
        parseSoup = parseSoup1
    else:
        print("O", end="")
        parseSoup = parseSoup2
    
    parseSoup(soup, parseData)
    
    if not isNextExists(soup):
        nextExists = False
        print()

    pageNum += 1

len(parseData)
# Out:
# OO
# 37

# %%
pprint(parseData)
# Out:
# [{'company': ('ООО СберОбразование',
#               'https://hh.ru/employer/5332874?hhtmFrom=vacancy_search_list'),
#   'experience': (6,),
#   'position': 'Программный эксперт на курс «Разработчик на Python»',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('Школа программирования Kodland',
#               'https://hh.ru/employer/3845543?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Преподаватель Python, Roblox, графический дизайн, Scratch, '
#               'математика, программирование для детей',
#   'salary': {'currency': '₽', 'scopes': (0, 100000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Бауманский учебный центр Специалист',
#               'https://hh.ru/employer/8219?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'Преподаватель курсов направления Python "Программирование на '
#               'языке Python для школьников"',
#   'salary': None,
#   'schedule': None},
#  {'company': ('ООО Онлайн-школа Фоксфорд',
#               'https://hh.ru/employer/5744540?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Репетитор по программированию Python и Scratch (6-11 классы)',
#   'salary': {'currency': '₽', 'scopes': (0, 70000), 'tax': None},
#   'schedule': None},
#  {'company': ('Alteasy',
#               'https://hh.ru/employer/1513283?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Middle python разработчик в AI-стартап (Part-time)',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('Alteasy',
#               'https://hh.ru/employer/1513283?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Senior/Pre-senior python разработчик в AI-стартап (Part-time)',
#   'salary': None,
#   'schedule': None},
#  {'company': ('EasyCode',
#               'https://hh.ru/employer/8977564?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель Scratch / Roblox / Unity / Веб-дизайн / '
#               'Геймдизайн / Разработка сайтов',
#   'salary': {'currency': '₽', 'scopes': (50000, 80000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Rebotica',
#               'https://hh.ru/employer/3571722?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Наставник основных занятий Онлайн',
#   'salary': {'currency': '₽', 'scopes': (0, 80000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Luxkod',
#               'https://hh.ru/employer/5817319?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель олимпиадного программирования (удалённо)',
#   'salary': {'currency': '₽', 'scopes': (0, 150000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Компьютерная Академия Top',
#               'https://hh.ru/employer/3192913?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Преподаватель детских компьютерных курсов',
#   'salary': {'currency': '₽', 'scopes': (30000, 75000), 'tax': None},
#   'schedule': None},
#  {'company': ('Онлайн-школа Тетрика',
#               'https://hh.ru/employer/3731347?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Репетитор по информатике, удаленно',
#   'salary': {'currency': '₽', 'scopes': (0, 72000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('GLT (Green Light Technology)',
#               'https://hh.ru/employer/3113091?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Технический писатель',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('GORA GROUP LLC',
#               'https://hh.ru/employer/9198474?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'Специалист по Искусственному Интеллекту (AI)',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('ЧУ ДО Московская школа программистов',
#               'https://hh.ru/employer/1358439?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель IT дисциплин',
#   'salary': {'currency': '₽', 'scopes': (0, 160000), 'tax': None},
#   'schedule': None},
#  {'company': ('ИП Ткачева Алла Сергеевна',
#               'https://hh.ru/employer/5578085?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Преподаватель программирования и робототехники',
#   'salary': {'currency': '₽', 'scopes': (30000, 70000), 'tax': None},
#   'schedule': None},
#  {'company': ('ООО Национальная тендерная компания',
#               'https://hh.ru/employer/1854585?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Data-science-специалист',
#   'salary': {'currency': '₽', 'scopes': (40000, 100000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('ЧУ ДО Московская школа программистов',
#               'https://hh.ru/employer/1358439?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель IT дисциплин',
#   'salary': {'currency': '₽', 'scopes': (0, 160000), 'tax': None},
#   'schedule': None},
#  {'company': ('DCloud',
#               'https://hh.ru/employer/4770322?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'DevOps engineer',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('АНО ПО Колледж Мировой Экономики и Передовых Технологий (КМЭПТ)',
#               'https://hh.ru/employer/10267285?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель по программированию / ИТ (It) дисциплин',
#   'salary': None,
#   'schedule': None},
#  {'company': ('ПАО «МТС» ',
#               'https://hh.ru/employer/3776?dpt=mts-3776-main&hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'ML Developer NLP (речевая аналитика) MTS AI',
#   'salary': None,
#   'schedule': 'Можно из дома'},
#  {'company': ('Skyeng',
#               'https://hh.ru/employer/1122462?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Учитель информатики (удаленно)',
#   'salary': {'currency': '₽', 'scopes': (60000, 120000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('ООО Ворк5',
#               'https://hh.ru/employer/689473?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Автор студенческих работ по программированию',
#   'salary': {'currency': '₽', 'scopes': (0, 90000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Skyeng',
#               'https://hh.ru/employer/1122462?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель программирования для детей (удаленно)',
#   'salary': {'currency': '₽', 'scopes': (0, 100000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Enjoy touch (ИП Анисимов Юрий Вадимович)',
#               'https://hh.ru/employer/1940353?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'Web-разработчик',
#   'salary': {'currency': '₽', 'scopes': (50000, 150000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Учи.Дома',
#               'https://hh.ru/employer/10719008?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Репетитор по информатике (удаленно)',
#   'salary': {'currency': '₽', 'scopes': (30000, 72000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('Decart IT-production',
#               'https://hh.ru/employer/1918903?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'DevOps Инженер',
#   'salary': {'currency': '₽', 'scopes': (190000, 240000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('ООО АЙТИ.СПЕЙС',
#               'https://hh.ru/employer/2000762?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Инженер БПЛА VTOL',
#   'salary': {'currency': '₽', 'scopes': (0, 200000), 'tax': None},
#   'schedule': None},
#  {'company': ('Школа 21',
#               'https://hh.ru/employer/4612390?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Младший менеджер по работе с экспертами',
#   'salary': None,
#   'schedule': None},
#  {'company': ('ПЭК / Офис',
#               'https://hh.ru/employer/3838?dpt=3838-3838-21488&hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Младший аналитик',
#   'salary': None,
#   'schedule': None},
#  {'company': ('Mayak',
#               'https://hh.ru/employer/8890167?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Урбан-аналитик данных',
#   'salary': {'currency': '₽', 'scopes': (100000, 0), 'tax': None},
#   'schedule': None},
#  {'company': ('ООО Центр программных решений',
#               'https://hh.ru/employer/2759703?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Преподаватель старших классов в онлайн-школу программирования',
#   'salary': {'currency': '₽', 'scopes': (20000, 100000), 'tax': None},
#   'schedule': None},
#  {'company': ('ООО ЛЕГАЛБЕТ',
#               'https://hh.ru/employer/3029476?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Devops Engineer/Devops Middle',
#   'salary': {'currency': '₽', 'scopes': (200000, 0), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('ОКС',
#               'https://hh.ru/employer/17859?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'Devops инженер в ДИТ',
#   'salary': {'currency': '₽', 'scopes': (200000, 400000), 'tax': None},
#   'schedule': None},
#  {'company': ('Дабл Ап',
#               'https://hh.ru/employer/1145559?hhtmFrom=vacancy_search_list'),
#   'experience': (3, 6),
#   'position': 'DevOps инженер на part-time',
#   'salary': {'currency': '₽', 'scopes': (0, 170000), 'tax': None},
#   'schedule': None},
#  {'company': ('Профилум',
#               'https://hh.ru/employer/1959134?hhtmFrom=vacancy_search_list'),
#   'experience': (),
#   'position': 'Менеджер вводного урока (удаленно, IT)',
#   'salary': {'currency': '₽', 'scopes': (75000, 120000), 'tax': None},
#   'schedule': 'Можно из дома'},
#  {'company': ('KiberOne (ИП Докучаева Юлия Викторовна)',
#               'https://hh.ru/employer/8981576?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Программист-наставник в школу программирования для детей',
#   'salary': {'currency': '₽', 'scopes': (0, 200000), 'tax': None},
#   'schedule': None},
#  {'company': ('ИП Ярославцева Елена Викторовна',
#               'https://hh.ru/employer/4584024?hhtmFrom=vacancy_search_list'),
#   'experience': (1, 3),
#   'position': 'Программист (Преподаватель в КиберШколе)',
#   'salary': {'currency': '₽', 'scopes': (120000, 0), 'tax': None},
#   'schedule': None}]

# %%
uri = f"mongodb+srv://mike1am:{os.getenv('MONGO_ATLAS_PSWD')}@cluster0.lcmtb1u.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
dbClient = MongoClient(uri, server_api=ServerApi("1"))

try:
    dbClient.admin.command("ping")
    print("Successfully connected!")
except OperationFailure as e:
    print(e)
# Out:
# Successfully connected!

# %%
db = dbClient["GB_test"]

collect = db.HW03_01
collect.drop()

# %%
collect.insert_many(parseData)
# Out:
# InsertManyResult([ObjectId('662799480dde0b2dd52ee308'), ObjectId('662799480dde0b2dd52ee309'), ObjectId('662799480dde0b2dd52ee30a'), ObjectId('662799480dde0b2dd52ee30b'), ObjectId('662799480dde0b2dd52ee30c'), ObjectId('662799480dde0b2dd52ee30d'), ObjectId('662799480dde0b2dd52ee30e'), ObjectId('662799480dde0b2dd52ee30f'), ObjectId('662799480dde0b2dd52ee310'), ObjectId('662799480dde0b2dd52ee311'), ObjectId('662799480dde0b2dd52ee312'), ObjectId('662799480dde0b2dd52ee313'), ObjectId('662799480dde0b2dd52ee314'), ObjectId('662799480dde0b2dd52ee315'), ObjectId('662799480dde0b2dd52ee316'), ObjectId('662799480dde0b2dd52ee317'), ObjectId('662799480dde0b2dd52ee318'), ObjectId('662799480dde0b2dd52ee319'), ObjectId('662799480dde0b2dd52ee31a'), ObjectId('662799480dde0b2dd52ee31b'), ObjectId('662799480dde0b2dd52ee31c'), ObjectId('662799480dde0b2dd52ee31d'), ObjectId('662799480dde0b2dd52ee31e'), ObjectId('662799480dde0b2dd52ee31f'), ObjectId('662799480dde0b2dd52ee320'), ObjectId('662799480dde0b2dd52ee321'), ObjectId('662799480dde0b2dd52ee322'), ObjectId('662799480dde0b2dd52ee323'), ObjectId('662799480dde0b2dd52ee324'), ObjectId('662799480dde0b2dd52ee325'), ObjectId('662799480dde0b2dd52ee326'), ObjectId('662799480dde0b2dd52ee327'), ObjectId('662799480dde0b2dd52ee328'), ObjectId('662799480dde0b2dd52ee329'), ObjectId('662799480dde0b2dd52ee32a'), ObjectId('662799480dde0b2dd52ee32b'), ObjectId('662799480dde0b2dd52ee32c')], acknowledged=True)

# %%
for doc in collect.find(
    {
        "$or": [
            {'experience': {"$size": 0}},
            {'experience.0': {"$lte": 1}}
        ]
    },
    {'position': 1, 'company': 1, 'salary.scopes': 1}
):
    pprint(doc)
# Out:
# {'_id': ObjectId('662799480dde0b2dd52ee309'),
#  'company': ['Школа программирования Kodland',
#              'https://hh.ru/employer/3845543?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель Python, Roblox, графический дизайн, Scratch, '
#              'математика, программирование для детей',
#  'salary': {'scopes': [0, 100000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee30b'),
#  'company': ['ООО Онлайн-школа Фоксфорд',
#              'https://hh.ru/employer/5744540?hhtmFrom=vacancy_search_list'],
#  'position': 'Репетитор по программированию Python и Scratch (6-11 классы)',
#  'salary': {'scopes': [0, 70000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee30c'),
#  'company': ['Alteasy',
#              'https://hh.ru/employer/1513283?hhtmFrom=vacancy_search_list'],
#  'position': 'Middle python разработчик в AI-стартап (Part-time)'}
# {'_id': ObjectId('662799480dde0b2dd52ee30d'),
#  'company': ['Alteasy',
#              'https://hh.ru/employer/1513283?hhtmFrom=vacancy_search_list'],
#  'position': 'Senior/Pre-senior python разработчик в AI-стартап (Part-time)'}
# {'_id': ObjectId('662799480dde0b2dd52ee30e'),
#  'company': ['EasyCode',
#              'https://hh.ru/employer/8977564?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель Scratch / Roblox / Unity / Веб-дизайн / Геймдизайн '
#              '/ Разработка сайтов',
#  'salary': {'scopes': [50000, 80000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee30f'),
#  'company': ['Rebotica',
#              'https://hh.ru/employer/3571722?hhtmFrom=vacancy_search_list'],
#  'position': 'Наставник основных занятий Онлайн',
#  'salary': {'scopes': [0, 80000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee310'),
#  'company': ['Luxkod',
#              'https://hh.ru/employer/5817319?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель олимпиадного программирования (удалённо)',
#  'salary': {'scopes': [0, 150000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee311'),
#  'company': ['Компьютерная Академия Top',
#              'https://hh.ru/employer/3192913?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель детских компьютерных курсов',
#  'salary': {'scopes': [30000, 75000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee312'),
#  'company': ['Онлайн-школа Тетрика',
#              'https://hh.ru/employer/3731347?hhtmFrom=vacancy_search_list'],
#  'position': 'Репетитор по информатике, удаленно',
#  'salary': {'scopes': [0, 72000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee313'),
#  'company': ['GLT (Green Light Technology)',
#              'https://hh.ru/employer/3113091?hhtmFrom=vacancy_search_list'],
#  'position': 'Технический писатель'}
# {'_id': ObjectId('662799480dde0b2dd52ee315'),
#  'company': ['ЧУ ДО Московская школа программистов',
#              'https://hh.ru/employer/1358439?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель IT дисциплин',
#  'salary': {'scopes': [0, 160000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee316'),
#  'company': ['ИП Ткачева Алла Сергеевна',
#              'https://hh.ru/employer/5578085?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель программирования и робототехники',
#  'salary': {'scopes': [30000, 70000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee317'),
#  'company': ['ООО Национальная тендерная компания',
#              'https://hh.ru/employer/1854585?hhtmFrom=vacancy_search_list'],
#  'position': 'Data-science-специалист',
#  'salary': {'scopes': [40000, 100000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee318'),
#  'company': ['ЧУ ДО Московская школа программистов',
#              'https://hh.ru/employer/1358439?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель IT дисциплин',
#  'salary': {'scopes': [0, 160000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee31a'),
#  'company': ['АНО ПО Колледж Мировой Экономики и Передовых Технологий (КМЭПТ)',
#              'https://hh.ru/employer/10267285?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель по программированию / ИТ (It) дисциплин'}
# {'_id': ObjectId('662799480dde0b2dd52ee31c'),
#  'company': ['Skyeng',
#              'https://hh.ru/employer/1122462?hhtmFrom=vacancy_search_list'],
#  'position': 'Учитель информатики (удаленно)',
#  'salary': {'scopes': [60000, 120000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee31d'),
#  'company': ['ООО Ворк5',
#              'https://hh.ru/employer/689473?hhtmFrom=vacancy_search_list'],
#  'position': 'Автор студенческих работ по программированию',
#  'salary': {'scopes': [0, 90000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee31e'),
#  'company': ['Skyeng',
#              'https://hh.ru/employer/1122462?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель программирования для детей (удаленно)',
#  'salary': {'scopes': [0, 100000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee320'),
#  'company': ['Учи.Дома',
#              'https://hh.ru/employer/10719008?hhtmFrom=vacancy_search_list'],
#  'position': 'Репетитор по информатике (удаленно)',
#  'salary': {'scopes': [30000, 72000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee322'),
#  'company': ['ООО АЙТИ.СПЕЙС',
#              'https://hh.ru/employer/2000762?hhtmFrom=vacancy_search_list'],
#  'position': 'Инженер БПЛА VTOL',
#  'salary': {'scopes': [0, 200000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee323'),
#  'company': ['Школа 21',
#              'https://hh.ru/employer/4612390?hhtmFrom=vacancy_search_list'],
#  'position': 'Младший менеджер по работе с экспертами'}
# {'_id': ObjectId('662799480dde0b2dd52ee324'),
#  'company': ['ПЭК / Офис',
#              'https://hh.ru/employer/3838?dpt=3838-3838-21488&hhtmFrom=vacancy_search_list'],
#  'position': 'Младший аналитик'}
# {'_id': ObjectId('662799480dde0b2dd52ee325'),
#  'company': ['Mayak',
#              'https://hh.ru/employer/8890167?hhtmFrom=vacancy_search_list'],
#  'position': 'Урбан-аналитик данных',
#  'salary': {'scopes': [100000, 0]}}
# {'_id': ObjectId('662799480dde0b2dd52ee326'),
#  'company': ['ООО Центр программных решений',
#              'https://hh.ru/employer/2759703?hhtmFrom=vacancy_search_list'],
#  'position': 'Преподаватель старших классов в онлайн-школу программирования',
#  'salary': {'scopes': [20000, 100000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee327'),
#  'company': ['ООО ЛЕГАЛБЕТ',
#              'https://hh.ru/employer/3029476?hhtmFrom=vacancy_search_list'],
#  'position': 'Devops Engineer/Devops Middle',
#  'salary': {'scopes': [200000, 0]}}
# {'_id': ObjectId('662799480dde0b2dd52ee32a'),
#  'company': ['Профилум',
#              'https://hh.ru/employer/1959134?hhtmFrom=vacancy_search_list'],
#  'position': 'Менеджер вводного урока (удаленно, IT)',
#  'salary': {'scopes': [75000, 120000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee32b'),
#  'company': ['KiberOne (ИП Докучаева Юлия Викторовна)',
#              'https://hh.ru/employer/8981576?hhtmFrom=vacancy_search_list'],
#  'position': 'Программист-наставник в школу программирования для детей',
#  'salary': {'scopes': [0, 200000]}}
# {'_id': ObjectId('662799480dde0b2dd52ee32c'),
#  'company': ['ИП Ярославцева Елена Викторовна',
#              'https://hh.ru/employer/4584024?hhtmFrom=vacancy_search_list'],
#  'position': 'Программист (Преподаватель в КиберШколе)',
#  'salary': {'scopes': [120000, 0]}}
